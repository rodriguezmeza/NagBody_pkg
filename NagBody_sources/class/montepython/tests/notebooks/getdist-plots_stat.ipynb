# %%
from __future__ import print_function
#Show plots inline, and load main getdist plot module and samples class
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys, os
sys.path.insert(0,os.path.realpath(os.path.join(os.getcwd(),'..')))
import numpy as np
from getdist import plots, MCSamples, chains
import getdist, IPython
print('Version: ',getdist.__version__)
# use this *after* importing getdist if you want to use interactive plots
# %matplotlib notebook
import matplotlib.pyplot as plt
import IPython
print('GetDist Version: %s, Matplotlib version: %s'%(getdist.__version__, plt.matplotlib.__version__))
# matplotlib 2 may not work very well without usetex on, can uncomment
# plt.rcParams['text.usetex']=True
# Out:
# Version:  1.1.2
# GetDist Version: 1.1.2, Matplotlib version: 3.1.3

# %%
download_dir = "./Results/sMGPT_IRR/getdist_analysis/"
histograms_dir="posteriors/"
huevos_dir="confidenceRegions/"

# %%
#Load from file
from getdist import loadMCSamples, chains, MCSamples

# Load individual samples:
# GR:
samples1 = loadMCSamples('./Results/sMGPT_IRR/Chains/GR_z05_IRR_bin01_MQ_sMGPT-MCExt', settings={'ignore_rows':0.3})
#samples2 = loadMCSamples('./Results/sMGPT_IRR/Chains/GR_z05_IRR_bin02_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})
#samples3 = loadMCSamples('./Results/sMGPT_IRR/Chains/GR_z10_IRR_bin01_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})
#samples4 = loadMCSamples('./Results/sMGPT_IRR/Chains/GR_z10_IRR_bin02_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})

# F4:
#samples5 = loadMCSamples('./Results/sMGPT_IRR/Chains/F4_z05_IRR_bin01_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})
#samples6 = loadMCSamples('./Results/sMGPT_IRR/Chains/F4_z05_IRR_bin02_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})
#samples7 = loadMCSamples('./Results/sMGPT_IRR/Chains/F4_z10_IRR_bin01_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})
#samples8 = loadMCSamples('./Results/sMGPT_IRR/Chains/F4_z10_IRR_bin02_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})

# F5:
#samples9 = loadMCSamples('./Results/sMGPT_IRR/Chains/F5_z05_IRR_bin01_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})
#samples10 = loadMCSamples('./Results/sMGPT_IRR/Chains/F5_z05_IRR_bin02_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})
#samples11 = loadMCSamples('./Results/sMGPT_IRR/Chains/F5_z10_IRR_bin01_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})
#samples12 = loadMCSamples('./Results/sMGPT_IRR/Chains/F5_z10_IRR_bin02_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})

# F6:
#samples13 = loadMCSamples('./Results/sMGPT_IRR/Chains/F6_z05_IRR_bin01_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})
#samples14 = loadMCSamples('./Results/sMGPT_IRR/Chains/F6_z05_IRR_bin02_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})
#samples15 = loadMCSamples('./Results/sMGPT_IRR/Chains/F6_z10_IRR_bin01_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})
#samples16 = loadMCSamples('./Results/sMGPT_IRR/Chains/F6_z10_IRR_bin02_MQH_sMGPT-MCExt', settings={'ignore_rows':0.3})


#samples = MCSamples.makeSingleSamples(self, names=names, filename="", single_thin=None)
# Out:
# ./Results/sMGPT_IRR/Chains/GR_z05_IRR_bin01_MQ_sMGPT-MCExt.txt
# Removed 0.3 as burn in

# %%
# GR:
histogram1=download_dir+histograms_dir+"GR_z05_IRR_bin01"+"_histograms.pdf"
#histogram2=download_dir+histograms_dir+"GR_z05_IRR_bin02"+"_histograms.pdf"
#histogram3=download_dir+histograms_dir+"GR_z10_IRR_bin01"+"_histograms.pdf"
#histogram4=download_dir+histograms_dir+"GR_z10_IRR_bin02"+"_histograms.pdf"

# F4:
#histogram5=download_dir+histograms_dir+"F4_z05_IRR_bin01"+"_histograms.pdf"
#histogram6=download_dir+histograms_dir+"F4_z05_IRR_bin02"+"_histograms.pdf"
#histogram7=download_dir+histograms_dir+"F4_z10_IRR_bin01"+"_histograms.pdf"
#histogram8=download_dir+histograms_dir+"F4_z10_IRR_bin02"+"_histograms.pdf"

# F5:
#histogram9=download_dir+histograms_dir+"F5_z05_IRR_bin01"+"_histograms.pdf"
#histogram10=download_dir+histograms_dir+"F5_z05_IRR_bin02"+"_histograms.pdf"
#histogram11=download_dir+histograms_dir+"F5_z10_IRR_bin01"+"_histograms.pdf"
#histogram12=download_dir+histograms_dir+"F5_z10_IRR_bin02"+"_histograms.pdf"

# F6:
#histogram13=download_dir+histograms_dir+"F6_z05_IRR_bin01"+"_histograms.pdf"
#histogram14=download_dir+histograms_dir+"F6_z05_IRR_bin02"+"_histograms.pdf"
#histogram15=download_dir+histograms_dir+"F6_z10_IRR_bin01"+"_histograms.pdf"
#histogram16=download_dir+histograms_dir+"F6_z10_IRR_bin02"+"_histograms.pdf"

# %%
# GR:
huevos1=download_dir+huevos_dir+"GR_z05_IRR_bin01"+"_huevos.pdf"
#huevos2=download_dir+huevos_dir+"GR_z05_IRR_bin02"+"_huevos.pdf"
#huevos3=download_dir+huevos_dir+"GR_z10_IRR_bin01"+"_huevos.pdf"
#huevos4=download_dir+huevos_dir+"GR_z10_IRR_bin02"+"_huevos.pdf"

# F4:
#huevos5=download_dir+huevos_dir+"F4_z05_IRR_bin01"+"_huevos.pdf"
#huevos6=download_dir+huevos_dir+"F4_z05_IRR_bin02"+"_huevos.pdf"
#huevos7=download_dir+huevos_dir+"F4_z10_IRR_bin01"+"_huevos.pdf"
#huevos8=download_dir+huevos_dir+"F4_z10_IRR_bin02"+"_huevos.pdf"

# F5:
#huevos9=download_dir+huevos_dir+"F5_z05_IRR_bin01"+"_huevos.pdf"
#huevos10=download_dir+huevos_dir+"F5_z05_IRR_bin02"+"_huevos.pdf"
#huevos11=download_dir+huevos_dir+"F5_z10_IRR_bin01"+"_huevos.pdf"
#huevos12=download_dir+huevos_dir+"F5_z10_IRR_bin02"+"_huevos.pdf"

# F6:
#huevos13=download_dir+huevos_dir+"F6_z05_IRR_bin01"+"_huevos.pdf"
#huevos14=download_dir+huevos_dir+"F6_z05_IRR_bin02"+"_huevos.pdf"
#huevos15=download_dir+huevos_dir+"F6_z10_IRR_bin01"+"_huevos.pdf"
#huevos16=download_dir+huevos_dir+"F6_z10_IRR_bin02"+"_huevos.pdf"

# %%
# Multiple 1D subplots

g = plots.get_subplot_plotter(width_inch=10)

# GR:
g.plots_1d(samples1, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
g.export(histogram1)
#g.plots_1d(samples2, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram2)
#g.plots_1d(samples3, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram3)
#g.plots_1d(samples4, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram4)

# F4:
#g.plots_1d(samples5, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram5)
#g.plots_1d(samples6, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram6)
#g.plots_1d(samples7, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram7)
#g.plots_1d(samples8, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram8)

# F5:
#g.plots_1d(samples9, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram9)
#g.plots_1d(samples10, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram10)
#g.plots_1d(samples11, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram11)
#g.plots_1d(samples12, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram12)

# F6:
#g.plots_1d(samples13, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram13)
#g.plots_1d(samples14, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram14)
#g.plots_1d(samples15, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram15)
#g.plots_1d(samples16, ['p1', 'p2', 'p3', 'p4','p5','p6'], nx=6);
#g.export(histogram16)

# %%
# Multiple 2D subplots
g = plots.get_subplot_plotter(subplot_size=2.0)
g.settings.scaling = False # prevent scaling down font sizes even though small subplots

# GR:
g.plots_2d(samples1, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
           nx=3, ny=2, filled=True);
g.export(huevos1)
#g.plots_2d(samples2, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos2)
#g.plots_2d(samples3, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos3)
#g.plots_2d(samples4, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos4)

# F4:
#g.plots_2d(samples5, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos5)
#g.plots_2d(samples6, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos6)
#g.plots_2d(samples7, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos7)
#g.plots_2d(samples8, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos8)
# Out:
# WARNING:root:2D kernel density bandwidth optimizer failed for p3, p4. Using fallback width: f(a) and f(b) must have different signs

# %%
# Multiple 2D subplots
g = plots.get_subplot_plotter(subplot_size=2.0)
g.settings.scaling = False # prevent scaling down font sizes even though small subplots

# F5:
#g.plots_2d(samples9, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos9)
#g.plots_2d(samples10, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos10)
#g.plots_2d(samples11, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos11)
#g.plots_2d(samples12, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos12)

# F6:
#g.plots_2d(samples13, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2,filled=True);
#g.export(huevos13)
#g.plots_2d(samples14, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos14)
#g.plots_2d(samples15, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos15)
#g.plots_2d(samples16, param_pairs=[['p1', 'p2'], ['p1', 'p3'],['p1', 'p4'], ['p2', 'p3'], ['p2', 'p4'], ['p3', 'p4']], 
#           nx=3, ny=2, filled=True);
#g.export(huevos16)

# %%
print(samples1.getInlineLatex('p1',limit=1))
#print(samples2.getInlineLatex('p1',limit=1))

print(samples1.getInlineLatex('p2',limit=1))
#print(samples2.getInlineLatex('p2',limit=1))

print(samples1.getInlineLatex('p3',limit=1))
#print(samples2.getInlineLatex('p3',limit=1))

print(samples1.getInlineLatex('p4',limit=2))
#print(samples2.getInlineLatex('p4',limit=2))

#print(samples2.getInlineLatex('p5',limit=1))
#print(samples2.getInlineLatex('p5',limit=2))

#print(samples2.getInlineLatex('p6',limit=1))
#print(samples2.getInlineLatex('p6',limit=2))
# Out:
# b_1 = 1.4749^{+0.0057}_{-0.0045}
# b_2 = 0.3137\pm 0.0089
# c_{0} = -25.26^{+0.55}_{-0.65}
# c_{2} = -35.7^{+1.2}_{-1.2}

# %%
print(samples1.PCA(['p1','p2','p3','p4','p5','p6']))
# Out:
# PCA for parameters:
#          1 :ln(b_1)
#          2 :ln(b_2)
#          3 :c_{0}
#          4 :c_{2}
#          5 :c_{4}
#          6 :\tilde{c}
#
# Correlation matrix for reduced parameters
#           p1 :  1.0000 -0.1133 -0.9138 -0.3727  0.0517  0.0524
#           p2 : -0.1133  1.0000 -0.1013  0.1040 -0.0247 -0.0953
#           p3 : -0.9138 -0.1013  1.0000  0.3775 -0.0580 -0.1535
#           p4 : -0.3727  0.1040  0.3775  1.0000 -0.0604 -0.3776
#           p5 :  0.0517 -0.0247 -0.0580 -0.0604  1.0000  0.0073
#           p6 :  0.0524 -0.0953 -0.1535 -0.3776  0.0073  1.0000
#
# e-values of correlation matrix
# PC 1:   0.0535
# PC 2:   0.5532
# PC 3:   0.9522
# PC 4:   1.0011
# PC 5:   1.1991
# PC 6:   2.2409
#
# e-vectors
#   1:  0.6919  0.1325  0.2484 -0.0534 -0.2787 -0.6012
#   2:  0.1656 -0.0752 -0.7775  0.3091 -0.5128  0.0630
#   3:  0.6956 -0.2114 -0.0074 -0.0403  0.3173  0.6075
#   4:  0.0163  0.7857  0.1779 -0.0874 -0.3773  0.4482
# ...
