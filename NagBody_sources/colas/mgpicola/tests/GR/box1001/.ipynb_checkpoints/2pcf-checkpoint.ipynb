# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
from nbodykit.lab import *
from nbodykit import setup_logging, style

import os
import matplotlib.pyplot as plt
plt.style.use(style.notebook)

import numpy as np

# %%
setup_logging() # turn on logging to screen

# %%
redshift = 0.5
cosmo = cosmology.Planck15

# %%
# define download dir for the data to the current directory
download_dir = "./output"
#download_dir = "/Users/mar/Research/Codigos/NagBody_pkg/NagBody_sources/colas/mglpicola_fofr/runs/mglpicola_fofr/B0256_P0256_M0256_testing/F5/box5001/output/."
#download_dir = "/Users/mar/Research/Codigos/NagBody_pkg/NagBody_sources/colas/mglpicola_fofr/runs/mglpicola_fofr/B0256_P0256_M0256/F5/box5001/output/."
#download_dir = "./gadget_data_27"

# %%
# NOTE: change this path if you downloaded the data somewhere else!
data_path = os.path.join(download_dir, 'snapshot_z0p000.0')
#data_path = os.path.join(download_dir, 'snapshot_z0p000.*')
#data_path = os.path.join(download_dir, 'gadget.*')


# initialize the Gadget1 catalog objects for data and randoms
data = Gadget1Catalog(data_path)
# Out:
# /anaconda2/envs/nbodykit-env/lib/python2.7/site-packages/nbodykit/io/gadget.py:152: UserWarning: Cannot decide the item size of `Mass`, assuming 4 bytes.
#   warnings.warn("Cannot decide the item size of `%s`, assuming 4 bytes." % (column))
# /anaconda2/envs/nbodykit-env/lib/python2.7/site-packages/nbodykit/io/gadget.py:152: UserWarning: Cannot decide the item size of `InternalEnergy`, assuming 4 bytes.
#   warnings.warn("Cannot decide the item size of `%s`, assuming 4 bytes." % (column))
# /anaconda2/envs/nbodykit-env/lib/python2.7/site-packages/nbodykit/io/gadget.py:152: UserWarning: Cannot decide the item size of `Density`, assuming 4 bytes.
#   warnings.warn("Cannot decide the item size of `%s`, assuming 4 bytes." % (column))
# /anaconda2/envs/nbodykit-env/lib/python2.7/site-packages/nbodykit/io/gadget.py:152: UserWarning: Cannot decide the item size of `SmoothingLength`, assuming 4 bytes.
#   warnings.warn("Cannot decide the item size of `%s`, assuming 4 bytes." % (column))
# [ 000029.44 ]   0: 10-16 13:16  CatalogSource   INFO     Extra arguments to FileType: ('./output/snapshot_z0p000.0',) {}

# %% [markdown]
# We can analyze the available columns in the catalogs via the ``columns`` attribute:

# %%
print('data columns = ', data.columns)
# Out:
# ('data columns = ', ['GadgetVelocity', 'ID', 'Mass', 'Position', 'Selection', 'Value', 'Weight'])

# %%
# convert to a MeshSource, using TSC interpolation on 256^3 mesh:: tsc or cic
#mesh = data.to_mesh(resampler='tsc', Nmesh=512, compensated=True, position='Position')
#mesh = data.to_mesh(resampler='tsc', Nmesh=1024, compensated=True, position='Position')
mesh = data.to_mesh(resampler='tsc', Nmesh=1024, compensated=True, position='Position',interlaced=True)

# %%
print("mesh = ", mesh)
# Out:
# ('mesh = ', (Gadget1Catalog(size=134217728, FileStack(Gadget1File(path=/Volumes/WD34/Results/MJ/B0200_P0512_M0512_nocut/GR/box1001/output/snapshot_z0p000.0, dataset=1, ncolumns=4, shape=(134217728,)>, ... 1 files)) as CatalogMesh))

# %%
# compute the power, specifying desired linear k-binning
#r = FFTPower(mesh, mode='1d', dk=0.005, kmin=0.01)
#r = FFTPower(mesh, mode='1d', dk=0.01, kmin=0.001)
r = SimulationBox2PCF(mesh, mode='1d', dk=0.01, kmin=0.001)
# Out:
# [ 000004.09 ]   0: 09-24 19:07  CatalogMesh     INFO     Chunk 0 ~ 4194304 / 134217728
# [ 000006.50 ]   0: 09-24 19:07  CatalogMesh     INFO     painted 4194304 out of 134217728 objects to mesh
# [ 000006.50 ]   0: 09-24 19:07  CatalogMesh     INFO     Chunk 4194304 ~ 8388608 / 134217728
# [ 000008.55 ]   0: 09-24 19:07  CatalogMesh     INFO     painted 8388608 out of 134217728 objects to mesh
# [ 000008.55 ]   0: 09-24 19:07  CatalogMesh     INFO     Chunk 8388608 ~ 12582912 / 134217728
# [ 000010.60 ]   0: 09-24 19:07  CatalogMesh     INFO     painted 12582912 out of 134217728 objects to mesh
# [ 000010.61 ]   0: 09-24 19:07  CatalogMesh     INFO     Chunk 12582912 ~ 16777216 / 134217728
# [ 000012.63 ]   0: 09-24 19:07  CatalogMesh     INFO     painted 16777216 out of 134217728 objects to mesh
# [ 000012.63 ]   0: 09-24 19:07  CatalogMesh     INFO     Chunk
]   0: 09-24 19:08  CatalogMesh     INFO     painted 121634816 out of 134217728 objects to mesh
# [ 000065.81 ]   0: 09-24 19:08  CatalogMesh     INFO     Chunk 121634816 ~ 125829120 / 134217728
# [ 000068.01 ]   0: 09-24 19:08  CatalogMesh     INFO     painted 125829120 out of 134217728 objects to mesh
# [ 000068.01 ]   0: 09-24 19:08  CatalogMesh     INFO     Chunk 125829120 ~ 130023424 / 134217728
# [ 000070.15 ]   0: 09-24 19:08  CatalogMesh     INFO     painted 130023424 out of 134217728 objects to mesh
# [ 000070.15 ]   0: 09-24 19:08  CatalogMesh     INFO     Chunk 130023424 ~ 134217728 / 134217728
# [ 000072.38 ]   0: 09-24 19:08  CatalogMesh     INFO     painted 134217728 out of 134217728 objects to mesh
# [ 000120.78 ]   0: 09-24 19:08  CatalogMesh     INFO     painted 134217728 out of 134217728 objects to mesh
# [ 000120.78 ]   0: 09-24 19:08  CatalogMesh     INFO     mean particles per cell is 0.125
# [ 000120.79 ]   0: 09-24 19:09  CatalogMesh     INFO     sum is 1.34218e+08
# [ 000121.64 ]   0: 09-24 19:09  CatalogMesh     INFO     normalized the convention to 1 + delta
# [ 000137.58 ]   0: 09-24 19:09  CatalogMesh     INFO     field: (Gadget1Catalog(size=134217728, FileStack(Gadget1File(path=/Users/mar/Research/Codigos/NagBody_pkg/NagBody_sources/colas/mglpicola/runs/Elephant_con_cola/cosma5/Elephant/GR/box1/snapshot_z0p000.0, dataset=1, ncolumns=4, shape=(134217728,)>, ... 1 files)) as CatalogMesh) painting done

# %%
# the result is stored at "power" attribute
Pk = r.power
print(Pk)
# Out:
# <BinnedStatistic: dims: (k: 1257), variables: ('k', 'power', 'modes')>

# %%
print(Pk.coords)
# Out:
# {'k': array([6.0000e-03, 1.6000e-02, 2.6000e-02, ..., 1.2546e+01, 1.2556e+01,
#        1.2566e+01])}

# %%
kvec=Pk['k']
pkvec=Pk['power'].real

#print(kvec[3])
#print(pkvec[3])

nk = kvec.shape[0]

print(nk)

pofka=np.array([kvec,pkvec])
pofkb=np.transpose(pofka)
print pofkb

np.savetxt('pofk.txt',pofkb,delimiter='\t',newline='\r\n')
# Out:
# 1257
# [[           nan            nan]
#  [           nan            nan]
#  [2.45436933e-02 5.48123021e+04]
#  ...
#  [1.25460173e+01 5.75835066e-01]
#  [1.25559870e+01 5.74787533e-01]
#  [1.25660075e+01 5.73055371e-01]]

# %%
# print out the meta-data
for k in Pk.attrs:
    print("%s = %s" %(k, str(Pk.attrs[k])))
# Out:
# Nmu = 1
# Nmesh = [1024 1024 1024]
# dk = 0.01
# kmin = 0.001
# BoxSize = [256. 256. 256.]
# volume = 16777216.0
# los = [0, 0, 1]
# kmax = None
# poles = []
# mode = 1d
# N1 = 134217728
# N2 = 134217728
# shotnoise = 0.125
# Lz = 256.0
# Lx = 256.0
# Ly = 256.0

# %%
fig1 = plt.figure()

# print the shot noise subtracted P(k)
plt.loglog(Pk['k'], Pk['power'].real - Pk.attrs['shotnoise'])
#plt.loglog(Pk['k'], Pk['power'].real)


# format the axes
plt.xlabel(r"$k$ [$h \ \mathrm{Mpc}^{-1}$]")
plt.ylabel(r"$P(k)$ [$h^{-3}\mathrm{Mpc}^3$]")
#plt.xlim(0.001, 0.6)
plt.xlim(0.01, 10.0)
plt.ylim(1,100000)

fig1.savefig("plot.pdf")
